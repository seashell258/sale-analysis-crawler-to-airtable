# %%
"https://members.helium10.com/listing-analyzer/la-api/analyze-asins?accountId=1545862407"

# %%
body = {
  "asins": [],
  "marketplaceId": "1",
  "searchSource": "landing_page",
  "mainAsin": "B06XRR8LN9",
  "sellerId": null
}

# %%
"https://members.helium10.com/listing-analyzer/la-api/get-sales-section?accountId=1545862407&searchId=1424603"
